# %% [markdown]
# Assignment 10

# %% [markdown]
# Name = komal s Tondwal
# Roll no= 2317129

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(df['sepal.length'])
# Out:
# <Axes: xlabel='sepal.length', ylabel='Count'>

# %%
sns.histplot(df['sepal.width'])
# Out:
# <Axes: xlabel='sepal.width', ylabel='Count'>

# %%
sns.histplot(df['petal.length'])
# Out:
# <Axes: xlabel='petal.length', ylabel='Count'>

# %%
sns.histplot(df['petal.width'])
# Out:
# <Axes: xlabel='petal.width', ylabel='Count'>

# %%
sns.boxplot(df['sepal.length'])
plt.title("Distribution of Iris Sepals")
plt.show()

# %%
sns.boxplot(df['sepal.length'])
# Out:
# <Axes: ylabel='sepal.length'>

# %%
sns.boxplot(data=df,x='petal.length',y='petal.width',hue='variety')
plt.title('Distribution of Iris Petals')
plt.xlable=('petal.length')
plt.ylable=('petal.width')
plt.show()

# %%
sns.pairplot(df,hue='variety')

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.histplot(data="Fare",bins=10,color="green",edgecolor="red")
plt.title("Distribution of Passengers using Histogram")
plt.show()

# %%
sns.boxplot(x='Sex', y='Age', data=df, color="blue",hue='Survived')
plt.title("Distribution of Passengers using Boxplot")
plt.xlabel=('Sex')
plt.ylabel=('Age')
plt.show()
# Out:
# C:\Users\komal\AppData\Local\Temp\ipykernel_25796\2489165732.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.boxplot(x='Sex', y='Age', data=df, color="blue",hue='Survived')

# %%
sns.scatterplot(data=df,x='Age',y='Fare')
plt.title("Distribution of Passengers using Scatterplot")
plt.xlabel=('Age')
plt.ylabel=('Fare')
plt.show()

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\komal\AppData\Local\Temp\ipykernel_25796\1826839585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.jointplot(x='Age',y='Fare',data=df)

# %%
sns.pairplot(df)

# %%
sns.barplot(data=df,x='Sex',y='Age',color='pink',edgecolor='blue')
plt.title("Distribution of Passengers using barplot")
plt.xlable=('Sex')
plt.ylable=('Age')
plt.show()

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.violinplot(data=df["Age"],color='purple')
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(data=df["Sex"],color='skyblue',edgecolor='red')
# Out:
# <Axes: ylabel='Sex'>

# %%
sns.violinplot(data=df,x="Sex",y="Age",color='purple')
plt.xlable=('Sex')
plt.ylable=('Age')
plt.show()

# %%
sns.stripplot(data=df,x="Sex",y="Age",color='green')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.swarmplot(data=df,x="Sex",y="Age",color="blue",edgecolor='red')
plt.title("Distribution of Passengers using Swarmplot")
plt.xlable=('Sex')
plt.ylable=('Age')
plt.show()
